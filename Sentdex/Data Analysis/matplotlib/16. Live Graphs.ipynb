# %% [markdown]
# #  Live Graphs
# ____

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.style as style
import webbrowser
from IPython.display import YouTubeVideo

# %%
def animate(i):
    graph_data = open('example.txt','r').read()
    lines = graph_data.split('\n')
    xs = []
    ys = []
    for line in lines:
        if len(line) > 1:
            x,y = line.split(',')# by delimeter
            xs.append(x)
            ys.append(y)
            
    ax1.clear()
    ax1.plot(xs, ys)

# %%
# %matplotlib
style.use('fivethirtyeight')
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

ani = animation.FuncAnimation(fig, animate, interval = 1000)
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
webbrowser.open("https://pythonprogramming.net/live-graphs-matplotlib-tutorial/")
# Out:
# True

# %% [markdown]
# points I wrote after reading the notes on the website
# 1. for data sources that update
# 2. for example live stock pricing or sensory data
# 3. abstraction to use animation (import matplotlib.animation as animation)
# 4. used the style 'fivethirtyeight'
# 5. fig is the plt(plot) and ax1 is the subplot
# 6. made an animate function to aggregate the data, clear the plot, and data passed in (data from a file)
# 7. 6 in short form build the data then plot it
# 8. made a major point of not using plt.show() in the animate function
# 9. Animation is run by putting the animation to the fig, running the function of 'animate', and also having an interval 1000 milliseconds
# 10. noticed that the clear is there in 'aniamte' because the graph is plotted according to the interval.
#
# summary from the vid
# 1. i on the animate function is interval
# 2. if len(line) > 1 used to handle to empty lines that my exist in the file (they are ignored in this case)
# 3. clear to get rid of previous drawings, is put before we plot the subplot
# 4. animation.FuncAnimation() animate based on a function in our case the function is 'aniamte'
# 6. Animate to fig and function to animate is 'animate' next parameter i
# 9. 1000 milliseconds is 1 second so every second the graph updates
# 10. updates in the background so need plt.show()
# 8. modified my code the data file also to be a parameter
# 9. Changed up my order as convention

# %%
YouTubeVideo('ZmYPzESC5YY')
